# %% [markdown]
# # Imports

# %%
# Import pandas
import pandas as pd

# Import matplotlib
import matplotlib.pyplot as plt

# Import Network X
import networkx as nx

# %% [markdown]
# # Paths for in/out files

# %%
# Path of IN-labels
names_path = '../src/visualization/mesh.pkl'

# Path for IN-tags
tags_path = '../src/visualization/geo.pkl'

# Path of OUT-labels - for Gephi
gephi_node_labels = '../s2ds19_AZ/Graphs/Gephi/InputData/gephi_node_labels_C.csv'

# Path of OUT-edges - for Gephi
gephi_weighted_edges = '../s2ds19_AZ/Graphs/Gephi/InputData/gephi_weighted_edges_C.csv'

# %% [markdown]
# # Read names_df

# %%
# Read
names_df = pd.read_pickle(names_path)

# Echo
names_df.head()
# Out:
#   category            mesh_heading  mesh_id         mesh_treenumbers
# 0        D              Calcimycin  D000001      D03.633.100.221.173
# 1        D                 Temefos  D000002      D02.705.400.625.800
# 2        J               Abattoirs  D000003  J01.576.423.200.700.100
# 3        L  Abbreviations as Topic  D000004  L01.559.598.400.556.131
# 4        A                 Abdomen  D000005              A01.923.047

# %% [markdown]
# # Construct Gephi labels

# %%
# Check all entries
print('Shape -Before-: ', names_df.shape)

# Check non-None entries
gephi_labels = names_df.dropna(axis=0)

# Check for duplicates
gephi_labels = gephi_labels.drop_duplicates(subset='mesh_id', keep='first')

# Check all entries - again
print('Shape  -After-: ', gephi_labels.shape)

# Copy only id and label
gephi_labels = gephi_labels.drop(columns='mesh_treenumbers category'.split())

# Rename for csv-file
gephi_labels = gephi_labels.rename(columns={'mesh_id':'id', 'mesh_heading':'label'})

# Save to .csv
gephi_labels['id label'.split()].to_csv('Gephi_Labels.csv', index=False)

# Echo
gephi_labels.head()
# Out:
# Shape -Before-:  (59748, 4)
# Shape  -After-:  (29349, 4)
#                     label       id
# 0              Calcimycin  D000001
# 1                 Temefos  D000002
# 2               Abattoirs  D000003
# 3  Abbreviations as Topic  D000004
# 4                 Abdomen  D000005

# %% [markdown]
# # Read tags_df

# %%
# Read
tags_df = pd.read_pickle(tags_path)

# Echo
tags_df.head()
# Out:
#       geo_id  nsamples        date  mesh_id      mesh_heading category method
# 0  200000001        38  2001/01/22  D011379         Prognosis        E   pmid
# 1  200000001        38  2001/01/22  D016000  Cluster Analysis        E   pmid
# 2  200000001        38  2001/01/22  D016000  Cluster Analysis        N   pmid
# 3  200000001        38  2001/01/22  D008297              Male      Sex   pmid
# 4  200000001        38  2001/01/22  D012333    RNA, Messenger        D   pmid

# %%
tags_df[tags_df['category']=='G']
# Out:
#            geo_id  nsamples        date  mesh_id  \
# 17      200000003       342  2001/07/19  D052138
# 18      200000003       342  2001/07/19  D009928
# 19      200000003       342  2001/07/19  D015536
# 22      200000003       342  2001/07/19  D015972
# 25      200000003       342  2001/07/19  D015398
# 33      200000010         4  2001/10/03  D015723
# 35      200000010         4  2001/10/03  D015870
# 38      200000010         4  2001/10/03  D015536
# 43      200000010         4  2001/10/03  D015854
# 51      200000014       765  2001/11/29  D002869
# 52      200000014       765  2001/11/29  D020224
# 56      200000014       765  2001/11/29  D014644
# 59      200000014       765  2001/11/29  D016678
# 61      200000014       765  2001/11/29  D015723
# 65      200000014       765  2001/11/29  D020641
# 67      200000014       765  2001/11/29  D002875
# 78      200000016        25  2002/02/12  D000782
# 82      200000016        25  2002/02/12  D014960
# 90      200000016        25  2002/02/12  D018628
# 91      200000016        25  2002/02/12  D011123
# 93      200000016        25  2002/02/12  D015894
# 96      200000016        25  2002/02/12  D022202
# 113     200000017         2  2002/02/01  D015870
# 115     200000031         5  2002/02/22  D015894
# 119     200000031         5  2002/02/22  D015870
# 121     200000031         5  2002/02/22  D017209
# 123     200000031         5  2002/02/22  D002470
# 124     200000031         5  2002/02/22  D014158
# 128     200000031         5  2002/02/22  D015723
# 132     200000031         5  2002/02/22  D002454
# ...           ...       ...         ...      ...
# 701400  200127747         2  2019/03/03  D001665
# 701402  200127747         2  2019/03/03  D019175
# 701403  200127747         2  2019/03/03  D002843
# 701410  200127747         2  2019/03/03  D012045
# 701411  200127747         2  2019/03/03  D002877
# 701413  200127747         2  2019/03/03  D000483
# 701415  200127747         2  2019/03/03  D020022
# 701416  200127748         1  2019/03/03  D015894
# 701418  200127748         1  2019/03/03  D005091
# 701421  200127748         1  2019/03/03  D014644
# 701431  200127748         1  2019/03/03  D020641
# 701432  200127748         1  2019/03/03  D002843
# 701434  200127748         1  2019/03/03  D019175
# 701438  200127748         1  2019/03/03  D002877
# 701440  200127748         1  2019/03/03  D014158
# 701444  200127748         1  2019/03/03  D011401
# 701445  200127748         1  2019/03/03  D020022
# 701448  200127748         1  2019/03/03  D001665
# 701449  200127748         1  2019/03/03  D000483
# 701451  200127748         1  2019/03/03  D012045
# 701456  200127763        12  2019/03/05  D015972
# 701466  200127763        12  2019/03/05  D015894
# 701468  200127763        12  2019/03/05  D019175
# 701474  200127828        24  2019/03/05  D015972
# 701491  200127828        24  2019/03/05  D019175
# 701492  200127828        24  2019/03/05  D015894
# 701494  200127829        36  2019/03/05  D015972
# 701502  200127829        36  2019/03/05  D019175
# 701509  200127829        36  2019/03/05  D015894
# 701537  200128021         6  2019/03/08  D009765
#
#                                   mesh_heading category method
# 17                             Genes, Neoplasm        G   pmid
# 18                           Organ Specificity        G   pmid
# 19                             Down-Regulation        G   pmid
# 22      Gene Expression Regulation, Neoplastic        G   pmid
# 25                         Signal Transduction        G   pmid
# 33                                Gene Library        G   pmid
# 35                             Gene Expression        G   pmid
# 38                             Down-Regulation        G   pmid
# 43                               Up-Regulation        G   pmid
# 51                      Chromosome Aberrations        G   pmid
# 52                     Expressed Sequence Tags        G   pmid
# 56                           Genetic Variation        G   pmid
# 59                                      Genome        G   pmid
# 61                                Gene Library        G   pmid
# 65             Polymorphism, Single Nucleotide        G   pmid
# 67                                 Chromosomes        G   pmid
# 78                                  Aneuploidy        G   pmid
# 82                                X Chromosome        G   pmid
# 90                                 Gene Dosage        G   pmid
# 91                                  Polyploidy        G   pmid
# 93                               Genome, Human        G   pmid
# 96          Chromosomes, Artificial, Bacterial        G   pmid
# 113                            Gene Expression        G   pmid
# 115                              Genome, Human        G   pmid
# 119                            Gene Expression        G   pmid
# 121                                  Apoptosis        G   pmid
# 123                              Cell Survival        G   pmid
# 124                     Transcription, Genetic        G   pmid
# 128                               Gene Library        G   pmid
# 132                       Cell Differentiation        G   pmid
# ...                                        ...      ...    ...
# 701400                           Binding Sites        G   pmid
# 701402                         DNA Methylation        G   pmid
# 701403                               Chromatin        G   pmid
# 701410      Regulatory Sequences, Nucleic Acid        G   pmid
# 701411                      Chromosomes, Human        G   pmid
# 701413                                 Alleles        G   pmid
# 701415       Genetic Predisposition to Disease        G   pmid
# 701416                           Genome, Human        G   pmid
# 701418                                   Exons        G   pmid
# 701421                       Genetic Variation        G   pmid
# 701431         Polymorphism, Single Nucleotide        G   pmid
# 701432                               Chromatin        G   pmid
# 701434                         DNA Methylation        G   pmid
# 701438                      Chromosomes, Human        G   pmid
# 701440                  Transcription, Genetic        G   pmid
# 701444               Promoter Regions, Genetic        G   pmid
# 701445       Genetic Predisposition to Disease        G   pmid
# 701448                           Binding Sites        G   pmid
# 701449                                 Alleles        G   pmid
# 701451      Regulatory Sequences, Nucleic Acid        G   pmid
# 701456  Gene Expression Regulation, Neoplastic        G   pmid
# 701466                           Genome, Human        G   pmid
# 701468                         DNA Methylation        G   pmid
# 701474  Gene Expression Regulation, Neoplastic        G   pmid
# 701491                         DNA Methylation        G   pmid
# 701492                           Genome, Human        G   pmid
# 701494  Gene Expression Regulation, Neoplastic        G   pmid
# 701502                         DNA Methylation        G   pmid
# 701509                           Genome, Human        G   pmid
# 701537                                 Obesity        G  dnorm
#
# [171755 rows x 7 columns]

# %% [markdown]
# # Filter DataFrame - Do it here since it still looks like the original thing...

# %%
# Construct date filter
mask_date = tags_df['date']==tags_df['date']

# Construct category filter
mask_category = tags_df['category']=='C'#tags_df['category']

# Filter data
tags_df = tags_df[mask_date & mask_category]

# Eliminate filterning columns
tags_df.drop(columns='date category method'.split(), inplace=True)

# %% [markdown]
# # Clean Data

# %%
# Check shape
print('Shape -before-: ', tags_df.shape)

# Drop NaNs
tags_df.dropna(axis=0,inplace=True)

# Delete duplicates
tags_df = tags_df.drop_duplicates()

# Only select summaries with +1 tag
tags_by_summary = tags_df['geo_id mesh_id'.split()].groupby('geo_id').count().reset_index() # Count tags per summary
good_summaries = tags_by_summary[tags_by_summary['mesh_id']>1] # Select abstracts with more than one tag
clean_tags = pd.merge(tags_df, good_summaries, on='geo_id') # Inner Join
clean_tags = clean_tags.drop(columns='mesh_id_y') # Drop column from inner join
clean_tags = clean_tags.rename(columns={'mesh_id_x':'mesh_id'}) # Rename key column
                             
# Check shape -again
print('Shape  -after-: ', tags_df.shape)

# Echo
tags_df.head()
# Out:
# Shape -before-:  (90162, 3)
# Shape  -after-:  (90084, 3)
#        geo_id  nsamples  mesh_id
# 2   200000001      38.0  D008545
# 4   200000001      38.0  D009361
# 6   200000001      38.0  D018450
# 10  200000001      38.0  D012878
# 12  200000001      38.0  D014604

# %% [markdown]
# # Construct DataFrame with Weighted Links

# %%
# Construct all-with-all links inside same geoid-nsample-date record
links = pd.merge(tags_df, tags_df, on='geo_id nsamples'.split())

# Echo info
print('     All links: ',links.shape[0])

# Rename to Source-Target
links.rename(columns={'mesh_id_x':'source', 'mesh_id_y':'target'}, inplace=True)

# Delete self-linkage
links.drop(links[links['source']==links['target']].index, inplace=True)

# Collapse repetitions while calculating weights
links_weights = links.groupby('source target'.split()).sum().reset_index()

# Rename sum(nsamples) to 'weight'
links_weights.rename(columns={'nsamples':'weight'}, inplace=True)

# Account for mirror-duplicates
links_weights['weight']/=2

# Normalize weights
links_weights['weight']/=links_weights['weight'].max()

# Save to .csv
links_weights.to_csv(gephi_weighted_edges, index=False)

# Echo info
print('Weighted links: ', links_weights.shape[0])

# Head
links_weights.head()
# Out:
#      All links:  322536
# Weighted links:  61332
#     source   target    weight
# 0  D000008  D000208  0.000411
# 1  D000008  D000310  0.000555
# 2  D000008  D001064  0.000411
# 3  D000008  D002471  0.000555
# 4  D000008  D006623  0.000555

# %% [markdown]
# # Construct Graph

# %%
# Construct Directed Graph
az = nx.from_pandas_edgelist(links_weights, 
                             source='source', 
                             target='target', 
                             edge_attr='weight', 
                             create_using=nx.DiGraph()
                            )

# Check for perfectly balanced links
#suma = 0.0
#n0='D000001'
#for n1 in az.neighbors(n0):
#    for n2 in az.neighbors(n1):
#        suma += az[n1][n2]['weight'] - az[n2][n1]['weight']
#print('Balanced graph: ', suma==0.0)

# Transform to undirected graph
azud = nx.to_undirected(az)

# Echo info
print('  Size (Nodes): ', azud.size())
print(' Order (Edges): ', azud.order())
# Out:
#   Size (Nodes):  61332
#  Order (Edges):  2322

# %% [markdown]
# # Run statistics

# %%
# Eigenvector centrality
eigencentrality = nx.eigenvector_centrality(azud, max_iter=500, weight='weight')

# %%
# PageRank
pagerank = nx.pagerank(azud, alpha=0.9)
