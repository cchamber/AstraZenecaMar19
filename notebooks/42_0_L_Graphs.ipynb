# %% [markdown]
# # Import the usual suspects

# %%
# Import pandas
import pandas as pd

# Import matplotlib
import matplotlib.pyplot as plt

# Import Network X
import networkx as nx

# %% [markdown]
# # Run script to construct Disease/Drug graphs

# %%
# Run
# %run ./41_0_L_Create_DD_Graph.py

# %% [markdown]
# # Run statistics on graphs

# %%
# Read Disease
disease_g = nx.read_gpickle(DISEASE_GRAPH)

# Read Drug
drug_g = nx.read_gpickle(DRUGS_GRAPH)

# %%
# Disease eigenvector centrality
disease_eig = nx.eigenvector_centrality(disease_g, max_iter=500, weight='weight')

# Drug eigenvector centrality
drug_eig = nx.eigenvector_centrality(drug_g, max_iter=500, weight='weight')

# %%
# Disease PageRank 
disease_pgn = nx.pagerank(disease_g, alpha=0.9, weight='weight')

# Drug PageRank 
drug_pgn = nx.pagerank(drug_g, alpha=0.9, weight='weight')

# %%
# Disease Degree 
disease_deg = nx.degree_centrality(disease_g)

# Drug Degree 
drug_deg = nx.degree_centrality(drug_g)

# %% [markdown]
# # Get Top Diseases/Drugs for time-series analysis

# %%
# Get n-top nodes according to a specific metric
def get_top(dictionary, top):
    items = list(dictionary.items())
    items.sort(reverse=True, key=lambda x: x[1])
    return list(map(lambda x:x[0], items[:top]))

# %%
# Choose n-top
n_top = 20

# Creatre multi-index
outside = [*['Diseases']*3,*['Drugs']*3]
inside = ['EigenCentrality','PageRank','Degree']*2
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# Create DataFrame with n-top diseases/drugs according to all the metrics
all_time_top = pd.DataFrame(data=[get_top(disease_eig, n_top),
                                  get_top(disease_pgn, n_top),
                                  get_top(disease_deg, n_top),
                                  get_top(drug_eig, n_top), 
                                  get_top(drug_pgn, n_top),
                                  get_top(drug_deg, n_top)], index=hier_index).transpose()

# Save as pickle file for Claire's time series analysis
all_time_top.to_pickle('All_Time_Top.pkl')

#Echo
all_time_top.head()
# Out:
#          Diseases                             Drugs
#   EigenCentrality PageRank   Degree EigenCentrality PageRank   Degree
# 0         D009369  D009369  D009369         D014157  D012333  D012333
# 1         D001943  D001943  D007249         D012333  D014157  D035683
# 2         D001932  D020022  D020022         D014408  D014408  D014157
# 3         D000230  D018450  D004195         D004268  D035683  D034741
# 4         D009362  D000230  D018450         D035683  D000970  D000970

# %%
df1 = all_time_top.Diseases.rename(columns={'PageRank':'mesh_id'})['mesh_id']

# %%
pd.merge(df1, mesh_df, on='mesh_id')
# Out:
#     mesh_id category                       mesh_heading  \
# 0   D009369        C                          Neoplasms
# 1   D001943        C                   Breast Neoplasms
# 2   D001943        C                   Breast Neoplasms
# 3   D020022        C  Genetic Predisposition to Disease
# 4   D020022        G  Genetic Predisposition to Disease
# 5   D018450        C                Disease Progression
# 6   D000230        C                     Adenocarcinoma
# 7   D002869        C             Chromosome Aberrations
# 8   D002869        G             Chromosome Aberrations
# 9   D001932        C                    Brain Neoplasms
# 10  D001932        C                    Brain Neoplasms
# 11  D001932        C                    Brain Neoplasms
# 12  D009362        C                Neoplasm Metastasis
# 13  D009362        C                Neoplasm Metastasis
# 14  D007249        C                       Inflammation
# 15  D008175        C                     Lung Neoplasms
# 16  D008175        C                     Lung Neoplasms
# 17  D008175        C                     Lung Neoplasms
# 18  D004195        C             Disease Models, Animal
# 19  D004195        E             Disease Models, Animal
# 20  D004195        E             Disease Models, Animal
# 21  D002277        C                          Carcinoma
# 22  D002471        C    Cell Transformation, Neoplastic
# 23  D002471        C    Cell Transformation, Neoplastic
# 24  D008113        C                    Liver Neoplasms
# 25  D008113        C                    Liver Neoplasms
# 26  D008113        C                    Liver Neoplasms
# 27  D015179        C               Colorectal Neoplasms
# 28  D015179        C               Colorectal Neoplasms
# 29  D015179        C               Colorectal Neoplasms
# 30  D015179        C               Colorectal Neoplasms
# 31  D015179        C               Colorectal Neoplasms
# 32  D015179        C               Colorectal Neoplasms
# 33  D002294        C           Carcinoma, Squamous Cell
# 34  D002294        C           Carcinoma, Squamous Cell
# 35  D009765        C                            Obesity
# 36  D009765        C                            Obesity
# 37  D009765        E                            Obesity
# 38  D009765        G                            Obesity
# 39  D011471        C                Prostatic Neoplasms
# 40  D011471        C                Prostatic Neoplasms
# 41  D011471        C                Prostatic Neoplasms
# 42  D011471        C                Prostatic Neoplasms
# 43  D015275        C               Tumor Lysis Syndrome
# 44  D015275        C               Tumor Lysis Syndrome
# 45  D006528        C          Carcinoma, Hepatocellular
# 46  D006528        C          Carcinoma, Hepatocellular
# 47  D006528        C          Carcinoma, Hepatocellular
# 48  D006528        C          Carcinoma, Hepatocellular
#
#                        mesh_treenumbers
# 0                                   C04
# 1                           C04.588.180
# 2                       C17.800.090.500
# 3                   C23.550.291.687.500
# 4                           G05.380.355
# 5                       C23.550.291.656
# 6                   C04.557.470.200.025
# 7                           C23.550.210
# 8                       G05.365.590.175
# 9                   C04.588.614.250.195
# 10                      C10.228.140.211
# 11                      C10.551.240.250
# 12                          C04.697.650
# 13                      C23.550.727.650
# 14                          C23.550.470
# 15                  C04.588.894.797.520
# 16                          C08.381.540
# 17                          C08.785.520
# 18                              C22.232
# 19                          E05.598.500
# 20                      E05.599.395.080
# 21                      C04.557.470.200
# 22                      C04.697.098.500
# 23                  C23.550.727.098.500
# 24                      C04.588.274.623
# 25                          C06.301.623
# 26                          C06.552.697
# 27              C04.588.274.476.411.307
# 28                  C06.301.371.411.307
# 29                  C06.405.249.411.307
# 30                  C06.405.469.158.356
# 31                  C06.405.469.491.307
# 32                  C06.405.469.860.180
# 33                  C04.557.470.200.400
# 34                  C04.557.470.700.400
# 35                      C18.654.726.500
# 36                  C23.888.144.699.500
# 37  E01.370.600.115.100.160.120.699.500
# 38          G07.100.100.160.120.699.500
# 39                  C04.588.945.440.770
# 40                      C12.294.260.750
# 41                      C12.294.565.625
# 42                      C12.758.409.750
# 43                      C15.604.515.880
# 44                      C20.683.515.950
# 45              C04.557.470.200.025.255
# 46                  C04.588.274.623.160
# 47                      C06.301.623.160
# 48                      C06.552.697.160

# %%
geo_df.groupby('mesh_id').count().head()
# Out:
#          geo_id  nsamples  date  mesh_heading  category  method
# mesh_id
# C483997       2         2     2             2         2       2
# C531600       2         2     2             2         2       2
# C531621       1         1     1             1         1       1
# C531623       2         2     2             0         0       2
# C531629       4         4     4             0         0       4

# %%
geo_df[geo_df['mesh_id']=='C483997']
# Out:
#           geo_id  nsamples        date  mesh_id  \
# 14322  200003369         6  2006/03/31  C483997
# 14323  200003369         6  2006/03/31  C483997
#
#                                  mesh_heading category method
# 14322  Wis heavy-chain disease protein, human        D  dnorm
# 14323  Wis heavy-chain disease protein, human        C  dnorm
